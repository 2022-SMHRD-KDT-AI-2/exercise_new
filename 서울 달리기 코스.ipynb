# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium import webdriver
import time as tm

# %%
url = 'http://www.marathon.pe.kr/course/atl.cgi?ct=2'

# %%
driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17292/1307687985.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
data  = driver.find_elements_by_css_selector('table.ads3tb1 > tbody > tr > td > table:nth-child(1) > tbody > tr')
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17292/2106925638.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   data  = driver.find_elements_by_css_selector('table.ads3tb1 > tbody > tr > td > table:nth-child(1) > tbody > tr')

# %%
cose=[]
location=[]
length=[]
time=[]
element=[]

# %%
cnt=1
for i in range(1,len(data)):
    data  = driver.find_elements_by_css_selector('table.ads3tb1 > tbody > tr > td > table:nth-child(1) > tbody > tr')
    lst=data[cnt]    
    id_=lst.find_element_by_class_name('ads3tb2:nth-child(2)').text
    
    aTag=driver.find_elements_by_xpath(f'//a[@href="atl.cgi?ct=2&md=second&id={id_}"]')
    
    adress1=lst.find_element_by_class_name('ads3tb2:nth-child(4)').text
    adress2=lst.find_element_by_class_name('ads3tb2:nth-child(5)').text
    adrs=adress1+' '+adress2
    
    cose.append(lst.find_element_by_class_name('ads3tb2:nth-child(3)').text)
    location.append(adrs)
    length.append(lst.find_element_by_class_name('ads3tb2:nth-child(6)').text)
    
    tm.sleep(1)
    aTag[0].click()
    tm.sleep(1)
    time.append(driver.find_element_by_css_selector('td.indtb2 > table.indtb2 > tbody > tr > td > font.smalltxtr > table > tbody > tr:nth-child(26) > td:nth-child(2)').text)
    element.append(driver.find_element_by_css_selector('body > center > table > tbody > tr > td.indtb2 > table.indtb2 > tbody > tr > td > font.smalltxtr > table > tbody > tr:nth-child(20) > td:nth-child(2)').text)
    driver.back()  
    tm.sleep(1)
    
    cnt+=1
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17292/4231880419.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   data  = driver.find_elements_by_css_selector('table.ads3tb1 > tbody > tr > td > table:nth-child(1) > tbody > tr')
# C:\Users\smhrd\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:446: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17292/4231880419.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   aTag=driver.find_elements_by_xpath(f'//a[@href="atl.cgi?ct=2&md=second&id={id_}"]')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17292/4231880419.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   time.append(driver.find_element_by_css_selector('td.indtb2 > table.indtb2 > tbody > tr > td > font.smalltxtr > table > tbody > tr:nth-child(26) > td:nth-child(2)').text)
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17292/4231880419.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   element.append(driver.find_element_by_css_selector('body > center > table > tbody > tr > td.indtb2 > table.indtb2 > tbody > tr > td > font.smalltxtr > table > tbody > tr:nth-child(20) > td:nth-child(2)').text)

# %%
element
# Out:
# ['시멘트, 우레탄.  ']

# %%
driver.find_element_by_xpath('/html/body/p/left/table/tbody/tr/td[2]/table[1]/tbody/tr/td[1]/font/a').click()
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17292/445282313.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('/html/body/p/left/table/tbody/tr/td[2]/table[1]/tbody/tr/td[1]/font/a').click()

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
data  = driver.find_elements_by_css_selector('table.ads3tb1 > tbody > tr > td > table:nth-child(1) > tbody > tr')
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17292/2106925638.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   data  = driver.find_elements_by_css_selector('table.ads3tb1 > tbody > tr > td > table:nth-child(1) > tbody > tr')

# %%
cnt=1
for i in range(1,len(data)):
    data  = driver.find_elements_by_css_selector('table.ads3tb1 > tbody > tr > td > table:nth-child(1) > tbody > tr')
    lst=data[cnt]    
    id_=lst.find_element_by_class_name('ads3tb2:nth-child(2)').text
    
    aTag=driver.find_elements_by_xpath(f'//a[@href="atl.cgi?ct=2&md=second&id={id_}"]')
    
    adress1=lst.find_element_by_class_name('ads3tb2:nth-child(4)').text
    adress2=lst.find_element_by_class_name('ads3tb2:nth-child(5)').text
    adrs=adress1+' '+adress2
    
    cose.append(lst.find_element_by_class_name('ads3tb2:nth-child(3)').text)
    location.append(adrs)
    length.append(lst.find_element_by_class_name('ads3tb2:nth-child(6)').text)
    
    tm.sleep(1)
    aTag[0].click()
    tm.sleep(1)
    time.append(driver.find_element_by_css_selector('td.indtb2 > table.indtb2 > tbody > tr > td > font.smalltxtr > table > tbody > tr:nth-child(26) > td:nth-child(2)').text)
    element.append(driver.find_element_by_css_selector('body > center > table > tbody > tr > td.indtb2 > table.indtb2 > tbody > tr > td > font.smalltxtr > table > tbody > tr:nth-child(20) > td:nth-child(2)').text)
    driver.back()  
    tm.sleep(1)
    
    cnt+=1
# Out:
# C:\Users\smhrd\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:446: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17292/212968302.py in <module>
#       2 for i in range(1,len(data)):
#       3     lst=data[cnt]
# ----> 4     id_=lst.find_element_by_class_name('ads3tb2:nth-child(2)').text
#       5
#       6     aTag=driver.find_elements_by_xpath(f'//a[@href="atl.cgi?ct=2&md=second&id={id_}"]')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element_by_class_name(self, name)
#     445         """
#     446         warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# --> 447         return self.find_element(by=By.CLASS_NAME, value=name)
#     448
#     449     def find_elements_by_class_name(self, name):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in find_element(self, by, value)
#     733             value = '[name="%s"]' % value
#     734
# --> 735         return self._execute(Command.FIND_CHILD_ELEMENT,
#     736                              {"using": by, "value": value})['value']
#     737
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=99.0.4844.51)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00E47AC3+2587331]
# 	Ordinal0 [0x00DDADD1+2141649]
# 	Ordinal0 [0x00CD3A80+1063552]
# 	Ordinal0 [0x00CC8222+1016354]
# 	Ordinal0 [0x00CC8A58+1018456]
# 	Ordinal0 [0x00CCA292+1024658]
# 	Ordinal0 [0x00CC3F79+999289]
# 	Ordinal0 [0x00CD4EF0+1068784]
# 	Ordinal0 [0x00D281D2+1409490]
# 	Ordinal0 [0x00D184A6+1344678]
# 	Ordinal0 [0x00CF53F6+1201142]
# 	Ordinal0 [0x00CF62E6+1204966]
# 	GetHandleVerifier [0x00FEDF22+1680738]
# 	GetHandleVerifier [0x010A0DBC+2413564]
# 	GetHandleVerifier [0x00EDD151+563089]
# 	GetHandleVerifier [0x00EDBF13+558419]
# 	Ordinal0 [0x00DE081E+2164766]
# 	Ordinal0 [0x00DE5508+2184456]
# 	Ordinal0 [0x00DE5650+2184784]
# 	Ordinal0 [0x00DEF5BC+2225596]
# 	BaseThreadInitThunk [0x766CFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77477A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77477A4E+238]

# %%
result = zip(cose, location, length, time, element)

# %%
result_list = list(result)

# %%
running_list=pd.DataFrame(result_list)

# %%
running_list
# Out:
#                       0                               1                 2  \
# 0              불광천에서 한강                           은평 응암                무한
# 1                   망우산                         구리시 구리시   12km 왕복1시간30분소요
# 2                양재천+탄천                        서울과천 도곡동              30km
# 3             아시아 선수촌공원                        송파구 잠실7동           749m 순환
# 4                왕방산 임로                   동두천시 불현동(탑동동)            15.5km
# 5         증산동 봉산 크로스컨트리                   은평고양덕양구 예)증산동             직선8km
# 6                강남 대모산                         강남구 일원동     자유롭게 10m~20km
# 7        서울대공원 동물원 순환도로                         과천시 막계동             6.5km
# 8             대현산 배수지공원         성동구 금호동 행당동 신당동 왕십리 옥수동            1.12km
# 9              서울시립대 코스                      동대문구 예)전농동             1.6km
# 10           우장산 공원 순환로                    서울시 강서구 내발산동            1.55km
# 11             서울대 순환도로                        관악구 신림9동             6.5km
# 12                남산조깅로                          중구 용산구             3.5km
# 13       한강북쪽코스에서 중랑천연결  성동구-중랑구-동대문구 옥수동 행당동 장안동 성수동등등              무한km
# 14               어린이대공원                          광진구 능동             2.5km
# 15     안양천기아대교아래 - 한강연결                         금천구 시흥동  기아대교아래-여의도대략22km
# 16     안양천기아대교아래 - 한강연결                         금천구 시흥동  기아대교아래-여의도대략22km
# 17             망우리 공원묘지                 중랑구구리시 경계 예)망우동            4.75km
# 18  대현산 공원(구 대현산 배수펌프장)                      서울 성동구 응봉동           1.120km
# 19              안양천변 코스                  금천구구로구 독산동~여의도               무한정
# 20            송파 성내천 코스                     송파구 풍납동 마천동             5.3km
# 21            우이천 자전거도로                     도봉구 쌍문동 .창동           왕복3.8km
# 22             난지캠핑장 코스                         마포구 합정동               5km
# 23         안산 등산로(서대문구)                         서대문구 홍제             3.7km
# 24            송파구 문정동코스                         송파구 문정동              17km
# 25         양재-사당간 남부순환로                         서울시 서초동             6~7km
# 26          용산가족공원 조깅코스                         용산구 용산동             1.4km
# 27           올림픽공원 조깅코스                         송파구 방이동             5.2km
# 28                여의도공원                         영등포 여의도             2.4km
# 29            석촌호수 순환코스                          송파구 잠실           2.532km
# 30            홍제천 자전거도로                        서대문구 홍제동               3km
# 31               양재천산책로                           강남 양재             6.9km
# 32           월드컵공원달리기코스                         마포구 상암동             5.8km
# 33               중랑천변코스                         중랑구 면목묵              15km
# 34              일자산 능선길                          하남시 하남               3km
# 35             탄천길과양재천길                         강남구 대치동              30km
# 36            에스퍼란자스 뜀길                          강동구 상일              25km
# 37           한강시민공원(강남)                         영등포 여의도              35km
# 38                남산산책로                           중구 필동             3.5km
# 39             보라매공원 트랙                         동작구 신대방            0.97km
# 40             강북한강고수부지                        마포용산 한강변             약15km
#
#                   3                        4
# 0              항상                시멘트, 우레탄.
# 1              없다                      흙길.
# 2            24시간               아스팔트, 우레탄.
# 3     24시간 언제나 가능                     우레탄.
# 4              --                      흙길.
# 5              없슴                      흙길.
# 6      누구나 달림이 환영                      흙길.
# 7     09:00~19:00                    아스팔트.
# 8            24시간                    아스팔트.
# 9             24시                아스팔트, 흙길.
# 10           24시간         아스팔트, 보도블럭, 시멘트.
# 11           제한없음                    아스팔트.
# 12           연중무휴                    아스팔트.
# 13           24시간                    아스팔트.
# 14  05:00 - 08:00           아스팔트, 흙길, 시멘트.
# 15             항시            시멘트, 우레탄, 잔디.
# 16             항시            시멘트, 우레탄, 잔디.
# 17           24시간                    아스팔트.
# 18           24시간                     우레탄.
# 19           24시간               보도블럭, 시멘트.
# 20            무제한                     우레탄.
# 21            언제나                    아스팔트.
# 22            무제한         아스팔트, 보도블럭, 시멘트.
# 23            무제한         흙길, 시멘트, 모래, 자갈.
# 24             종일    아스팔트, 보도블럭, 시멘트, 우레탄.
# 25             종일              아스팔트, 보도블럭.
# 26           24시간                      흙길.
# 27        저녁10시까지          아스팔트, 시멘트, 우레탄.
# 28        24시간 개방                    아스팔트.
# 29             종일                     우레탄.
# 30            무제한               아스팔트, 시멘트.
# 31            무제한                    아스팔트.
# 32             --                아스팔트, 흙길.
# 33            무제한               아스팔트, 우레탄.
# 34             --                      흙길.
# 35           24시간          아스팔트, 시멘트, 우레탄.
# 36            무제한                 흙길, 시멘트.
# 37           24시간            아스팔트, 흙길, 잔디.
# 38            무제한                    아스팔트.
# 39           24시간            아스팔트, 흙길, 잔디.
# 40            무제한                 흙길, 시멘트.
